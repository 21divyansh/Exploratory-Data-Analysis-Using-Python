# %% [raw]
# Task 1: What is the total annual salary for all the employees of each department? Display the result using a bar graph?

# %%
import pandas as pd
emp_df=pd.read_excel('DS1_C4_S5_Employee_Data_Practice.xlsx')
emp_df
# Out:
#     Employee_Code   Gender Department  Annual Salary ($)  Age  Work_Experience
# 0             1010    Male        IT               27000   22                0
# 1             1011  Female        IT               48000   27                4
# 2             1012    Male      Sales              75000   31                7
# 3             1013    Male      Sales              61000   29                6
# 4             1014  Female    Finance              45000   27                4
# ..             ...     ...        ...                ...  ...              ...
# 65            1074  Female         HR              82500   43               13
# 66            1075    Male      Sales              53500   28                5
# 67            1076  Female         HR              57000   29                6
# 68            1077    Male      Sales              66500   33                7
# 69            1078    Male    Finance              92000   45               19
#
# [70 rows x 6 columns]

# %%
dep_data=emp_df.groupby('Department')['Annual Salary ($)'].sum()
dep_data
# Out:
# Department
# Finance     790000
# HR          987000
# IT         1282900
# Sales      1089000
# Name: Annual Salary ($), dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
dep_data.plot(x='Department',kind='bar',stacked=False,title='Grouped bar chart',
xlabel='Department',ylabel='Total Annual salary')
# Out:
# <Axes: title={'center': 'Grouped bar chart'}, xlabel='Department', ylabel='Total Annual salary'>

# %%
# Interpretation: The IT department has the employees with highest annual salary i.e, 1,28,2900/-

# %% [markdown]
# Task 2: The company wants to analyze gender equality across several departments. Display the departments-wise total number of male and female employees using a DataFrame.

# %%
gen_data=emp_df.groupby(['Department','Gender'])['Gender'].count()
gen_data
# Out:
# Department  Gender
# Finance     Female     2
#             Male      11
# HR          Female    11
#             Male       4
# IT          Female    10
#             Male      12
# Sales       Female     4
#             Male      16
# Name: Gender, dtype: int64

# %%
dic1={'Department':['Finance','HR','IT','Sales'],'Male':[11,4,12,16],'Female':[2,11,10,4]}
dic1
# Out:
# {'Department': ['Finance', 'HR', 'IT', 'Sales'],
#  'Male': [11, 4, 12, 16],
#  'Female': [2, 11, 10, 4]}

# %%
dic1_df=pd.DataFrame(dic1)
dic1_df
# Out:
#   Department  Male  Female
# 0    Finance    11       2
# 1         HR     4      11
# 2         IT    12      10
# 3      Sales    16       4

# %%
dic1_df.plot(x='Department',kind='bar',stacked=True,title='Grouped Stacked',xlabel='Department',ylabel='Gender')
plt.show()

# %% [markdown]
# Task 3: What salary do you think the company might offer a new employee(a candidate with no work experience) of the IT department?

# %%
filt_data=emp_df[(emp_df['Department']=='IT ')&(emp_df['Work_Experience']==0)]
filt_data
# Out:
#     Employee_Code   Gender Department  Annual Salary ($)  Age  Work_Experience
# 0             1010    Male        IT               27000   22                0
# 7             1017    Male        IT               28000   23                0
# 12            1022    Male        IT               29000   22                0
# 46            1055    Male        IT               27500   22                0
# 47            1056  Female        IT               29000   23                0

# %%
filt_data['Annual Salary ($)'].mean()
# Out:
# 28100.0

# %%
# Interpretation: The annual salary for IT department with 0 experience is 28,100/-

# %% [markdown]
# Task 4: Display the department wise ratio of the sum of annual salaries for all employees in each department, using a pie chart.

# %%
sum_sal=emp_df.groupby('Department')['Annual Salary ($)'].sum()
sum_sal
# Out:
# Department
# Finance     790000
# HR          987000
# IT         1282900
# Sales      1089000
# Name: Annual Salary ($), dtype: int64

# %%
dep=['Finance','HR','IT','Sales',]
sum_salary=[790000,987000,1282900,1089000]

# %%
plt.pie(sum_salary,labels=dep,autopct='%.2f%%')
plt.title('Pie_chart')
plt.show()

# %% [markdown]
# Task 5: Display the distribution of employee count by age group using a histogram.

# %%
plt.hist(emp_df['Age'])
plt.xlabel('Age of Employees')
plt.ylabel('Number of employee')
plt.title('Histogram')
plt.show()

# %% [markdown]
# Task6: Display the salary trend based on employee experience using scatter plot.

# %%
emp_df.plot(x='Annual Salary ($)',y='Work_Experience',kind='scatter',title='Scatter plot',xlabel='salary',ylabel='experience')
plt.show()

# %% [markdown]
# Task 7: Determine the department-wise spread of all employee's salaries using a seperate box plot for each department.

# %%
emp_df.boxplot(column='Annual Salary ($)',by='Department')
# Out:
# <Axes: title={'center': 'Annual Salary ($)'}, xlabel='Department'>

# %%
# Interpretation: There are two outliers identified in the HR department and IT department.
